# %%
using PyPlot

# %%
using HDF5

# %%
using FileIO, ImageMagick, ImageIO, Colors

# %%
#    Pixel Size: 
    
δ_x = [0.0271,0.0216,0.114,3*0.0303] 
δ_y = [0.0305,0.0234,0.125,3*0.0298];

# %%
#   Resolution: 
    
σ_x = [0.0874, 0.0861, 0.303, 3*0.202]
σ_y = [0.0895, 0.0918,  0.201, 3*0.189];

# %%
res_px_x = round.(σ_x ./ δ_x, sigdigits=3)
# Out:
# 4-element Array{Float64,1}:
#  3.23
#  3.99
#  2.66
#  6.67

# %%
res_px_y = round.(σ_y ./ δ_y, sigdigits=3)
# Out:
# 4-element Array{Float64,1}:
#  2.93
#  3.92
#  1.61
#  6.34

# %% [markdown]
# # Camera #1 (BTV 50):

# %%
img_path = "../data/resolution/Screen_BTV-50-53.png"
img = Gray.(load(img_path))
img_frame = convert(Array{Float64},img);

# %%
fig, ax = plt.subplots(1,1, figsize=(7,7))

ax.imshow(img_frame)

ax.set_xlabel("x")
ax.set_ylabel("y")
# Out:
# Figure(PyObject <Figure size 700x700 with 1 Axes>)
# PyObject Text(24.000000000000007, 0.5, 'y')

# %% [markdown]
# ## x-projection:

# %%
img_path = "../data/resolution/TT41.BTV412350_S1_F75_B.png"
img = Gray.(load(img_path))
img_x = convert(Array{Float64},img);

# %%
fig, ax = plt.subplots(1,1, figsize=(7,7))

ax.imshow(img_x)

ax.set_xlabel("x")
ax.set_ylabel("y")
# Out:
# Figure(PyObject <Figure size 700x700 with 1 Axes>)
# PyObject Text(24.000000000000007, 0.5, 'y')

# %% [markdown]
# ## y-projection:

# %%
img_path = "../data/resolution/TT41.BTV412350_S1_F75_T.png"
img = Gray.(load(img_path))
img_y = convert(Array{Float64},img);

# %%
fig, ax = plt.subplots(1,1, figsize=(7,7))

ax.imshow(img_y)

ax.set_xlabel("x")
ax.set_ylabel("y")
# Out:
# Figure(PyObject <Figure size 700x700 with 1 Axes>)
# PyObject Text(24.000000000000007, 0.5, 'y')

# %% [markdown]
# # Camera #2 (BTV 53):

# %% [markdown]
# ## x-projection:

# %%
img_path = "../data/resolution/TT41.BTV412353_S1_F75_LT_Corner.png"
img = Gray.(load(img_path))
img_x = convert(Array{Float64},img);

# %%
fig, ax = plt.subplots(1,1, figsize=(7,7))

ax.imshow(img_x)

ax.set_xlabel("x")
ax.set_ylabel("y")
# Out:
# Figure(PyObject <Figure size 700x700 with 1 Axes>)
# PyObject Text(24.000000000000007, 0.5, 'y')

# %% [markdown]
# ## y-projection:

# %%
img_path = "../data/resolution/TT41.BTV412353_S1_F75.png"
img = Gray.(load(img_path))
img_y = convert(Array{Float64},img);

# %%
fig, ax = plt.subplots(1,1, figsize=(7,7))

ax.imshow(img_y)

ax.set_xlabel("x")
ax.set_ylabel("y")
# Out:
# Figure(PyObject <Figure size 700x700 with 1 Axes>)
# PyObject Text(24.000000000000007, 0.5, 'y')

# %% [markdown]
# # Camera #3 (BTV 26):

# %%
img_path = "../data/resolution/Screen_BTV-26-is2.png"
img = Gray.(load(img_path))
img_frame = convert(Array{Float64},img);

# %%
fig, ax = plt.subplots(1,1, figsize=(7,7))

ax.imshow(img_frame)

ax.set_xlabel("x")
ax.set_ylabel("y")
# Out:
# Figure(PyObject <Figure size 700x700 with 1 Axes>)
# PyObject Text(24.0, 0.5, 'y')

# %% [markdown]
# ## x-projection:

# %%
fid = h5open("../data/resolution/calib-data.h5", "r") do file
    read(file, "btv26")
end

img = convert.(Float64, fid)';

# %%
fig, ax = plt.subplots(1,1, figsize=(7,7))

ax.imshow(img)

ax.set_xlabel("x")
ax.set_ylabel("y")
# Out:
# Figure(PyObject <Figure size 700x700 with 1 Axes>)
# PyObject Text(24.000000000000007, 0.5, 'y')

# %% [markdown]
# ## y-projection:

# %% [markdown]
# # Camera #4 (IS2):

# %% [markdown]
#     Scintillating Chromox (Al2O3:CrO2) screen

# %%
fid = h5open("../data/resolution/calib-data.h5", "r") do file
    read(file, "is2")
end

img = convert.(Float64, fid)';

# %% [markdown]
# ## x-projection:

# %%
fig, ax = plt.subplots(1,1, figsize=(7,7))

ax.imshow(img)

ax.set_xlabel("x")
ax.set_ylabel("y")
# Out:
# Figure(PyObject <Figure size 700x700 with 1 Axes>)
# PyObject Text(24.000000000000007, 0.5, 'y')

# %% [markdown]
# ## y-projection:
